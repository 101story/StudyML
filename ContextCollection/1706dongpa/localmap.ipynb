# %%
import pandas as pd
import numpy as np

# %%
joined = pd.read_csv(r'C:\Users\jhee\Documents\StudyFolder\Project_DongpaBangjiP\DBP\join.csv', 
                     encoding='UTF-8')
joined.head(10)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
def save_fig(fig_id, tight_layout=True):
    path = os.path.join(".", fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)

joined.plot(kind = "scatter", x = "x_pos", y = "y_pos",alpha=0.1)
save_fig("pajuJoinData", False)
# Out:
# Saving figure pajuJoinData

# %%
checked = joined[joined['check']==1]

# %%
checked.plot(kind = "scatter", x = "x_pos", y = "y_pos",alpha=0.1)
save_fig("pajuJCheckData")
# Out:
# Saving figure pajuJCheckData

# %%
pd.value_counts(joined.loc[joined.check == '1'])

# %%
df={'s':[[0,1],[1.2]], 'a':[1,2]}
frame = pd.DataFrame(df)
frame
# Out:
#    a       s
# 0  1  [0, 1]
# 1  2   [1.2]

# %%
type(frame['s'])
# Out:
# pandas.core.series.Series

# %%
frame
# Out:
#    a       s  new
# 0  1  [0, 1]    1
# 1  2   [1.2]    1

# %%
frame['new'] = [[1,2],[1,2]]

# %%
frame
# Out:
#    a       s     new
# 0  1  [0, 1]  [1, 2]
# 1  2   [1.2]  [1, 2]

# %%
frame['new'] = [[1.2], [1,3]]
